# %% [markdown]
# Matplotlib
# ==========
#
# The granddaddy of all Python visualization.
#
# - Initial release: 2003 by [John D. Hunter](https://en.wikipedia.org/wiki/John_D._Hunter)
# - Current version: [![PyPi](https://badge.fury.io/py/matplotlib.svg)](https://badge.fury.io/py/matplotlib)
# - Repository: https://github.com/matplotlib/matplotlib

# %% [markdown]
# Most common usage
# -----------------
#
# `matplotlib` was initially created to mimic the plotting functionality from `Matlab`, and a lot of its syntax is still retained in the lastest version.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 100)
y = np.sin(x)
plt.plot(x, y, "r--")

# %% [markdown]
# it has a lot of built-in plot functions that helps simplify visualization process, and the syntax is almost identical to those from `Matlab`

# %%
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)>

# %%
plt.hist
# Out:
# <function matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)>

# %%
plt.hist2d
# Out:
# <function matplotlib.pyplot.hist2d(x, y, bins=10, range=None, density=False, weights=None, cmin=None, cmax=None, *, data=None, **kwargs)>

# %%
plt.contour
# Out:
# <function matplotlib.pyplot.contour(*args, data=None, **kwargs)>

# %%
plt.contourf
# Out:
# <function matplotlib.pyplot.contourf(*args, data=None, **kwargs)>

# %%
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, *, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, interpolation_stage=None, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %% [markdown]
# Since version 2.0, `matplotlib` has been pusing to a more OOP style plotting, which gives users a lot more flexibility in customizing the plots.

# %%
fig = plt.figure()
rect = fig.patch  # a rectangle instance
rect.set_facecolor('lightgoldenrodyellow')

ax1 = fig.add_axes([0.1, 0.3, 0.4, 0.4])
rect = ax1.patch
rect.set_facecolor('lightslategray')

ax1.tick_params(axis='x', labelcolor='tab:red', labelrotation=45, labelsize=16)
ax1.tick_params(axis='y', color='tab:green', size=25, width=3)

# %% [markdown]
# you can also generate 3D plot, but the default method does not provide interactivity as what `Matlab` does.

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Plot a sin curve using the x and y axes.
x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
ax.plot(x, y, zs=0, zdir='z', label='curve in (x, y)')

# Plot scatterplot data (20 2D points per colour) on the x and z axes.
colors = ('r', 'g', 'b', 'k')

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.sample(20 * len(colors))
y = np.random.sample(20 * len(colors))
c_list = []
for c in colors:
    c_list.extend([c] * 20)
# By using zdir='y', the y value of these points is fixed to the zs value 0
# and the (x, y) points are plotted on the x and z axes.
ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x, z)')

ax.view_init(elev=20., azim=-35)

# %% [markdown]
# Although the default `matplotlib` can only provide static images, it is possible to use 3rd-party plugins to provide interacitivity similar to `Matlab`'s plot viewer.
#
# For integration with Jupyter, the best option would be `ipympl`

# %%
# %matplotlib ipympl

# %% [markdown]
# one can also use `%matplotlib widget` to switch to `ipympl` backend in jupyter.

# %%
x = np.linspace(-np.pi, np.pi, 100)
y = np.sin(x)
plt.plot(x, y, "r--")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# originally, `ipympl` requires additional build step to be properly loaded into `jupyterlab`, but the most recent version of `ipympl` and `jupyterlab` has much better integration and can work directly without manual compiling.

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Plot a sin curve using the x and y axes.
x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
ax.plot(x, y, zs=0, zdir='z', label='curve in (x, y)')

# Plot scatterplot data (20 2D points per colour) on the x and z axes.
colors = ('r', 'g', 'b', 'k')

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.sample(20 * len(colors))
y = np.random.sample(20 * len(colors))
c_list = []
for c in colors:
    c_list.extend([c] * 20)
# By using zdir='y', the y value of these points is fixed to the zs value 0
# and the (x, y) points are plotted on the x and z axes.
ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x, z)')

ax.view_init(elev=20., azim=-35)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Almost all of the native plotting functions are now supported by `ipympl`, and the viewing widgets are responsive most of the time when the underlying data is reasonably small.
#
# Here is the backend table extracted from the documentation page
#
#
# | Backend | Description |
# | ------- | ----------- |
# | QtAgg   |  Agg rendering in a Qt canvas (requires PyQt or `Qt for Python`, a.k.a. PySide).  This backend can be activated in IPython with `%matplotlib qt`.|
# | __ipympl__  |  Agg rendering embedded in a Jupyter widget (requires ipympl). This backend can be enabled in a Jupyter notebook with  `%matplotlib ipympl`. |
# | GTK3Agg | Agg rendering to a GTK 3.x canvas (requires PyGObject and pycairo).  This backend can be activated in IPython with `%matplotlib gtk3`. |
# | GTK4Agg | Agg rendering to a GTK 4.x canvas (requires PyGObject and pycairo).  This backend can be activated in IPython with `%matplotlib gtk4`. |
# | macosx  | Agg rendering into a Cocoa canvas in OSX.  This backend can be activated in IPython with `%matplotlib osx`. |
# | TkAgg   | Agg rendering to a Tk_ canvas (requires TkInter). This backend can be activated in IPython with `%matplotlib tk`. |
# | __nbAgg__   | Embed an interactive figure in a Jupyter classic notebook.  This backend can be enabled in Jupyter notebooks via `%matplotlib notebook`. |
# | WebAgg  | On `show()` will start a tornado server with an interactive figure. |
# | GTK3Cairo | Cairo rendering to a GTK 3.x canvas (requires PyGObject and pycairo). |
# | GTK4Cairo | Cairo rendering to a GTK 4.x canvas (requires PyGObject and pycairo). |
# | wxAgg     | Agg rendering to a wxWidgets canvas (requires wxPython 4). This backend can be activated in IPython with `%matplotlib wx`.|

# %% [markdown]
# Due to the vast number of built-in functions available, it is not possible to memorize all of them.
# So the best way to use `matplotlib` is to
#
# - Google, which will most likely redirect you to a thread in stackoverflow that presents a working but outdated method.
# - [__recommended__] visit the [gallery](https://matplotlib.org/stable/gallery/index.html) and look for the example.
